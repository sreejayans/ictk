# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # GROUP 7 MEMBERS

# %% [markdown]
# # 1.SREEJAYAN S

# %% [markdown]
# # 2.RAHMATHUNNISAH

# %% [markdown]
# # 3.NEETHU RAJ

# %% [markdown]
# # 4.PRINCY.P

# %%
data=pd.read_csv(r'C:\Users\sreejayan\Desktop\data set\hotel-tips.csv')

# %%
data.head()
# Out:
#    Unknown  bill_id  total_bill   tip     sex smoker  day    time  size
# 0      110    10111       16.99  1.01  Female     No  Sun  Dinner     2
# 1      111    10112       10.34  1.66    Male     No  Sun  Dinner     3
# 2      112    10113       21.01  3.50    Male     No  Sun  Dinner     3
# 3      113    10114       23.68  3.31    Male     No  Sun  Dinner     2
# 4      114    10115       24.59  3.61  Female     No  Sun  Dinner     4

# %%
data.shape
# Out:
# (244, 9)

# %%
data.columns
# Out:
# Index(['Unknown', 'bill_id', 'total_bill', 'tip', 'sex', 'smoker', 'day',
#        'time', 'size'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unknown     244 non-null    int64
#  1   bill_id     244 non-null    int64
#  2   total_bill  244 non-null    float64
#  3   tip         244 non-null    float64
#  4   sex         244 non-null    object
#  5   smoker      244 non-null    object
#  6   day         244 non-null    object
#  7   time        244 non-null    object
#  8   size        244 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 17.3+ KB

# %%
data.describe()
# Out:
#           Unknown       bill_id  total_bill         tip        size
# count  244.000000    244.000000  244.000000  244.000000  244.000000
# mean   231.500000  10232.500000   19.785943    2.998279    2.569672
# std     70.580923     70.580923    8.902412    1.383638    0.951100
# min    110.000000  10111.000000    3.070000    1.000000    1.000000
# 25%    170.750000  10171.750000   13.347500    2.000000    2.000000
# 50%    231.500000  10232.500000   17.795000    2.900000    2.000000
# 75%    292.250000  10293.250000   24.127500    3.562500    3.000000
# max    353.000000  10354.000000   50.810000   10.000000    6.000000

# %%
plt.figure(figsize=(25,6))
plt.bar(data['size'],data['total_bill'])
plt.xlabel('SIZE',fontsize =20)
plt.ylabel('BILL',fontsize =20)
plt.show()

# %%
plt.bar(data['day'],data['total_bill'])
plt.xlabel('DAY',fontsize =20)
plt.ylabel('TOTAL BILL',fontsize =20)
plt.show()

# %%
data
# Out:
#      Unknown  bill_id  total_bill   tip     sex smoker   day    time  size
# 0        110    10111       16.99  1.01  Female     No   Sun  Dinner     2
# 1        111    10112       10.34  1.66    Male     No   Sun  Dinner     3
# 2        112    10113       21.01  3.50    Male     No   Sun  Dinner     3
# 3        113    10114       23.68  3.31    Male     No   Sun  Dinner     2
# 4        114    10115       24.59  3.61  Female     No   Sun  Dinner     4
# ..       ...      ...         ...   ...     ...    ...   ...     ...   ...
# 239      349    10350       29.03  5.92    Male     No   Sat  Dinner     3
# 240      350    10351       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241      351    10352       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242      352    10353       17.82  1.75    Male     No   Sat  Dinner     2
# 243      353    10354       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 9 columns]

# %%
plt.bar(data['day'],data['tip'])
plt.xticks(rotation=90)
plt.xlabel('DAY',fontsize =15)
plt.ylabel('TIP',fontsize =15)
plt.show()

# %%
plt.bar(data['sex'],data['tip'])
plt.title('Sex VS TIP')
plt.xticks(rotation=90)
plt.ylabel('TIP',fontsize =15)
plt.show()

# %% [markdown]
# Day wise

# %%
plt.figure(figsize=(15,6))
plt.title('Day wise')
sns.countplot(x=data.day)
plt.show()

# %%
data
# Out:
#      Unknown  bill_id  total_bill   tip     sex smoker   day    time  size
# 0        110    10111       16.99  1.01  Female     No   Sun  Dinner     2
# 1        111    10112       10.34  1.66    Male     No   Sun  Dinner     3
# 2        112    10113       21.01  3.50    Male     No   Sun  Dinner     3
# 3        113    10114       23.68  3.31    Male     No   Sun  Dinner     2
# 4        114    10115       24.59  3.61  Female     No   Sun  Dinner     4
# ..       ...      ...         ...   ...     ...    ...   ...     ...   ...
# 239      349    10350       29.03  5.92    Male     No   Sat  Dinner     3
# 240      350    10351       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241      351    10352       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242      352    10353       17.82  1.75    Male     No   Sat  Dinner     2
# 243      353    10354       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 9 columns]

# %%
plt.bar(data['time'],data['tip'])
plt.xticks(rotation=90)
plt.xlabel('Time',fontsize =15)
plt.ylabel('Tip',fontsize =15)
plt.show()

# %%
sns.pairplot(data)

# %%
data
# Out:
#      Unknown  bill_id  total_bill   tip     sex smoker   day    time  size
# 0        110    10111       16.99  1.01  Female     No   Sun  Dinner     2
# 1        111    10112       10.34  1.66    Male     No   Sun  Dinner     3
# 2        112    10113       21.01  3.50    Male     No   Sun  Dinner     3
# 3        113    10114       23.68  3.31    Male     No   Sun  Dinner     2
# 4        114    10115       24.59  3.61  Female     No   Sun  Dinner     4
# ..       ...      ...         ...   ...     ...    ...   ...     ...   ...
# 239      349    10350       29.03  5.92    Male     No   Sat  Dinner     3
# 240      350    10351       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241      351    10352       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242      352    10353       17.82  1.75    Male     No   Sat  Dinner     2
# 243      353    10354       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 9 columns]

# %%
data.head(50)
# Out:
#     Unknown  bill_id  total_bill   tip     sex smoker  day    time  size
# 0       110    10111       16.99  1.01  Female     No  Sun  Dinner     2
# 1       111    10112       10.34  1.66    Male     No  Sun  Dinner     3
# 2       112    10113       21.01  3.50    Male     No  Sun  Dinner     3
# 3       113    10114       23.68  3.31    Male     No  Sun  Dinner     2
# 4       114    10115       24.59  3.61  Female     No  Sun  Dinner     4
# 5       115    10116       25.29  4.71    Male     No  Sun  Dinner     4
# 6       116    10117        8.77  2.00    Male     No  Sun  Dinner     2
# 7       117    10118       26.88  3.12    Male     No  Sun  Dinner     4
# 8       118    10119       15.04  1.96    Male     No  Sun  Dinner     2
# 9       119    10120       14.78  3.23    Male     No  Sun  Dinner     2
# 10      120    10121       10.27  1.71    Male     No  Sun  Dinner     2
# 11      121    10122       35.26  5.00  Female     No  Sun  Dinner     4
# ...

# %%
data.groupby(by='sex').sum()
# Out:
# C:\Users\sreejayan\AppData\Local\Temp\ipykernel_2704\124116989.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby(by='sex').sum()
#         Unknown  bill_id  total_bill     tip  size
# sex
# Female    20713   890800     1570.95  246.51   214
# Male      35773  1605930     3256.82  485.07   413

# %%
plt.figure(figsize=(15,6))
sns.countplot(x=data.smoker)
plt.show()

# %%
df3=data[data['sex']=='Female']
plt.figure(figsize=(8,6))
sns.countplot(x='day',data=df3)
plt.show()

# %%
df3=data[data['sex']=='Male']
plt.figure(figsize=(6,6))
sns.countplot(x='day',data=df3)
plt.show()

# %%
data
# Out:
#      Unknown  bill_id  total_bill   tip     sex smoker   day    time  size
# 0        110    10111       16.99  1.01  Female     No   Sun  Dinner     2
# 1        111    10112       10.34  1.66    Male     No   Sun  Dinner     3
# 2        112    10113       21.01  3.50    Male     No   Sun  Dinner     3
# 3        113    10114       23.68  3.31    Male     No   Sun  Dinner     2
# 4        114    10115       24.59  3.61  Female     No   Sun  Dinner     4
# ..       ...      ...         ...   ...     ...    ...   ...     ...   ...
# 239      349    10350       29.03  5.92    Male     No   Sat  Dinner     3
# 240      350    10351       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241      351    10352       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242      352    10353       17.82  1.75    Male     No   Sat  Dinner     2
# 243      353    10354       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 9 columns]

# %%
df4=data[data['size']>4]
#plt.figure(figsize=(6,6))
sns.countplot(x='day',data=df4)
plt.show()

# %%
plt.bar(data['day'],data['size'])
plt.xlabel("day")
plt.ylabel("number of persons ")
plt.xticks(rotation=90)
plt.show()

# %%
sns.boxplot(x='day',y='total_bill',data=data)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>
