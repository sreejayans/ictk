# %% [markdown]
# # Assignment on Measures of Central Tendency and Dispersion

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
stud=pd.read_csv(r'C:\Users\sreejayan\Desktop\assignment\StudentsPerformance.csv')

# %%
stud.head(50)
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0   female        group C            some high school  free/reduced
# 1   female        group B                 high school  free/reduced
# 2   female        group B            some high school  free/reduced
# 3   female        group B                some college      standard
# 4   female        group C                some college  free/reduced
# 5   female        group B                 high school  free/reduced
# 6   female        group B            some high school  free/reduced
# 7   female        group D          associate's degree  free/reduced
# 8   female        group D            some high school  free/reduced
# 9   female        group C                 high school      standard
# 10  female        group C            some high school  free/reduced
# 11  female        group D           bachelor's degree  free/reduced
# 12  female        group B            some high school      standard
# 13  female        group C                some college  free/reduced
# 14  female        group E            some high school  free/reduced
# 15  female        group C                 high school  free/reduced
# 16  female        group A                 high school  free/reduced
# 17  female        group C                 high school  free/reduced
# 18  female        group C                 high school  free/reduced
# 19  female        group C                some college  free/reduced
# 20  female        group C                 high school  free/reduced
# 21  female        group D            some high school  free/reduced
# 22  female        group C                 high school  free/reduced
# 23  female        group A          associate's degree  free/reduced
# 24  female        group B            some high school      standard
# 25  female        group E           bachelor's degree      standard
# 26  female        group A            some high school  free/reduced
# 27  female        group B                 high school  free/reduced
# 28  female        group E            some high school  free/reduced
# 29  female        group C          associate's degree      standard
# 30  female        group D                 high school  free/reduced
# 31  female        group B          associate's degree      standard
# 32  female        group C             master's degree  free/reduced
# 33  female        group C          associate's degree      standard
# 34  female        group D             master's degree  free/reduced
# 35  female        group D            some high school  free/reduced
# 36  female        group A          associate's degree  free/reduced
# 37  female        group B            some high school      standard
# 38  female        group C                 high school  free/reduced
# 39  female        group E                 high school  free/reduced
# 40  female        group B                 high school      standard
# 41  female        group C                 high school  free/reduced
# 42  female        group C                some college  free/reduced
# 43  female        group D          associate's degree  free/reduced
# 44  female        group E                some college  free/reduced
# 45  female        group C           bachelor's degree  free/reduced
# 46  female        group C            some high school  free/reduced
# 47  female        group C           bachelor's degree  free/reduced
# 48  female        group D          associate's degree  free/reduced
# 49  female        group A            some high school  free/reduced
#
#    test preparation course  math score  reading score  writing score
# 0                     none           0             17             10
# 1                     none           8             24             23
# 2                     none          18             32             28
# 3                     none          11             38             32
# 4                     none          22             39             33
# 5                completed          23             44             36
# 6                     none          24             38             27
# 7                     none          26             31             38
# 8                     none          19             34             32
# 9                     none          29             29             30
# 10               completed          29             40             44
# 11                    none          29             41             47
# 12               completed          32             51             44
# 13                    none          32             39             33
# 14                    none          32             34             38
# 15                    none          33             41             43
# 16               completed          34             48             41
# 17                    none          34             42             39
# 18                    none          26             61             54
# 19                    none          25             44             43
# 20                    none          22             53             46
# 21               completed          35             55             60
# 22                    none          36             53             43
# 23                    none          37             57             56
# 24                    none          37             46             46
# 25                    none          37             45             38
# 26                    none          38             43             43
# 27                    none          38             60             50
# 28                    none          38             49             45
# 29                    none          39             64             57
# 30                    none          39             52             46
# 31                    none          40             48             50
# 32                    none          40             58             54
# 33                    none          40             59             51
# 34                    none          40             59             54
# 35               completed          32             65             64
# 36                    none          41             51             48
# 37                    none          41             55             51
# 38                    none          33             46             43
# 39                    none          41             45             40
# 40                    none          24             52             51
# 41                    none          42             62             60
# 42               completed          34             66             69
# 43               completed          42             61             58
# 44               completed          42             55             54
# 45               completed          43             51             54
# 46                    none          43             53             53
# 47                    none          31             62             61
# 48                    none          43             60             58
# 49                    none          44             64             58

# %%
stud.describe()
# Out:
#         math score  reading score  writing score
# count  1000.000000    1000.000000    1000.000000
# mean     66.001000      69.195000      68.119000
# std      15.569567      14.706436      15.226381
# min       0.000000      17.000000      10.000000
# 25%      57.000000      59.000000      58.000000
# 50%      66.000000      70.000000      69.000000
# 75%      77.000000      79.250000      79.000000
# max     100.000000     100.000000     100.000000

# %%
# Count the number of males and females
num_males = (stud['gender'] == 'male').sum()
num_females = (stud['gender'] == 'female').sum()

print(f"Number of males: {num_males}")
print(f"Number of females: {num_females}")
# Out:
# Number of males: 482
# Number of females: 518

# %% [markdown]
# # 1. Find out how many males and females participated in the test.

# %%
num_males = ((stud['gender'] == 'male') & (stud['test preparation course'] == 'completed')).sum()
num_females = ((stud['gender'] == 'female') & (stud['test preparation course'] == 'completed')).sum()
print("number of males",num_males)
print("number of females",num_females)
# Out:
# number of males 174
# number of females 184

# %% [markdown]
# # 2. What do you think about the students' parental level of education?

# %%
parental_education_counts = stud["parental level of education"].value_counts()
print(parental_education_counts)
# Out:
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental level of education, dtype: int64

# %%
parental_education_counts.plot(kind="bar")
plt.title("Distribution of Parental Education Levels")
plt.xlabel("Education Level")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# # 3. Who scores the most on average for math, reading and writing based on
# ● Gender
# ● Test preparation course

# %%
# Group the data by gender and calculate the mean scores for each subject
mean_scores = stud.groupby(['gender','test preparation course'])['math score', 'reading score', 'writing score'].mean()
print(mean_scores)
# Out:
#                                 math score  reading score  writing score
# gender test preparation course
# female completed                 67.108696      77.375000      78.793478
#        none                      61.320359      69.955090      68.982036
# male   completed                 72.988506      70.793103      70.339080
#        none                      66.467532      62.581169      59.551948
# C:\Users\sreejayan\AppData\Local\Temp\ipykernel_1664\136322799.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   mean_scores = stud.groupby(['gender','test preparation course'])['math score', 'reading score', 'writing score'].mean()

# %% [markdown]
# # 4. What do you think about the scoring variation for math, reading and writing based on
# ● Gender
# ● Test preparation course

# %%
# Group the data by gender and test preparation course, and calculate the VARIANCE scores for each subject
var_scores = stud.groupby(['gender', 'test preparation course'])['math score', 'reading score', 'writing score'].var()
# Print the variance
print(var_scores)
# Out:
#                                 math score  reading score  writing score
# gender test preparation course
# female completed                208.173913     161.175546     149.836897
#        none                     272.602767     214.241220     225.495172
# male   completed                197.098133     185.297987     166.098233
#        none                     205.513600     184.843553     181.394687
# C:\Users\sreejayan\AppData\Local\Temp\ipykernel_1664\672994258.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   var_scores = stud.groupby(['gender', 'test preparation course'])['math score', 'reading score', 'writing score'].var()

# %% [markdown]
# # 5. The management needs your help to give bonus points to the top 25% of students based on their math score, so how will you help the management to achieve this.

# %%
# Sort the data by math score in descending order
sorted_data = stud.sort_values(by='math score', ascending=False)

# Calculate the 25th percentile of the math scores
math_25_percentile = np.percentile(stud['math score'], 25)

# Create a new column to indicate whether each student is in the top 25% based on their math score
sorted_data['top_25_math'] = sorted_data['math score'] >= math_25_percentile

# Assign bonus points to the students who are in the top 25% based on their math score
sorted_data.loc[sorted_data['top_25_math'], 'math score'] += 10

# Print the updated data frame with bonus points
print(sorted_data)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 999    male        group E           bachelor's degree      standard
# 996    male        group A                some college      standard
# 515  female        group E                some college      standard
# 517  female        group E          associate's degree      standard
# 516  female        group E           bachelor's degree      standard
# ..      ...            ...                         ...           ...
# 2    female        group B            some high school  free/reduced
# 51   female        group C            some high school  free/reduced
# 3    female        group B                some college      standard
# 1    female        group B                 high school  free/reduced
# 0    female        group C            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 999               completed         110            100            100
# 996               completed         110             96             86
# 515                    none         110             92             97
# 517                    none         110            100            100
# 516                    none         110            100            100
# ..                      ...         ...            ...            ...
# 2                      none          18             32             28
# 51                     none          13             41             51
# 3                      none          11             38             32
# 1                      none           8             24             23
# 0                      none           0             17             10
#
#      top_25_math
# 999         True
# 996         True
# 515         True
# 517         True
# 516         True
# ..           ...
# 2          False
# 51         False
# 3          False
# 1          False
# 0          False
#
# [1000 rows x 9 columns]

# %%
sorted_data.head(50)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 999    male        group E           bachelor's degree      standard
# 996    male        group A                some college      standard
# 515  female        group E                some college      standard
# 517  female        group E          associate's degree      standard
# 516  female        group E           bachelor's degree      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 995    male        group E                some college      standard
# 513  female        group E           bachelor's degree      standard
# 514  female        group E                 high school      standard
# 994    male        group C          associate's degree      standard
# 993    male        group C                some college      standard
# 512  female        group D                some college      standard
# 992    male        group E          associate's degree      standard
# 991    male        group E                some college      standard
# 989    male        group A          associate's degree      standard
# 510  female        group B           bachelor's degree      standard
# 511  female        group D            some high school      standard
# 990    male        group C          associate's degree      standard
# 509  female        group C          associate's degree      standard
# 508  female        group C           bachelor's degree      standard
# 988    male        group C           bachelor's degree      standard
# 507  female        group E          associate's degree      standard
# 987    male        group D             master's degree      standard
# 505  female        group B          associate's degree      standard
# 506  female        group E             master's degree      standard
# 982    male        group B            some high school      standard
# 983    male        group C           bachelor's degree      standard
# 985    male        group E          associate's degree      standard
# 986    male        group E                 high school      standard
# 984    male        group E            some high school      standard
# 504  female        group E          associate's degree      standard
# 503  female        group D           bachelor's degree  free/reduced
# 980    male        group C                some college      standard
# 981    male        group E                some college  free/reduced
# 978    male        group C          associate's degree      standard
# 979    male        group E            some high school      standard
# 499  female        group A            some high school      standard
# 502  female        group E           bachelor's degree  free/reduced
# 501  female        group D             master's degree      standard
# 500  female        group C           bachelor's degree      standard
# 973    male        group B                some college      standard
# 497  female        group C          associate's degree      standard
# 498  female        group C          associate's degree      standard
# 975    male        group C           bachelor's degree      standard
# 977    male        group E          associate's degree  free/reduced
# 974    male        group C                some college      standard
# 972    male        group B          associate's degree      standard
# 976    male        group C             master's degree      standard
# 971    male        group A           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score  \
# 999               completed         110            100            100
# 996               completed         110             96             86
# 515                    none         110             92             97
# 517                    none         110            100            100
# 516                    none         110            100            100
# 997               completed         110             97             99
# 998               completed         110            100             93
# 995               completed         109             87             81
# 513               completed         109            100            100
# 514                    none         109             93             90
# 994               completed         108             87             90
# 993               completed         108             86             90
# 512                    none         108            100             99
# 992               completed         107             82             88
# 991                    none         107             87             82
# 989               completed         107             92             86
# 510                    none         107             97             96
# 511               completed         107            100            100
# 990                    none         107             93             91
# 509               completed         106             96             99
# 508               completed         106            100            100
# 988               completed         106             90             92
# 507               completed         105             89             92
# 987                    none         105             81             84
# 505               completed         104             87             92
# 506               completed         104             99            100
# 982               completed         104             86             87
# 983               completed         104             90             91
# 985               completed         104             85             82
# 986                    none         104             73             71
# 984                    none         104             88             78
# 504               completed         103            100             95
# 503               completed         103            100            100
# 980               completed         103             84             90
# 981                    none         103             90             83
# 978                    none         102             79             84
# 979                    none         102             87             78
# 499               completed         102            100             97
# 502               completed         102            100            100
# 501                    none         102            100            100
# 500               completed         102            100             99
# 973               completed         101             96             91
# 497                    none         101             86             84
# 498                    none         101             95             94
# 975               completed         101             81             79
# 977               completed         101             73             80
# 974                    none         101             74             76
# 972               completed         101             89             92
# 976               completed         101             85             85
# 971                    none         101             96             92
#
#      top_25_math
# 999         True
# 996         True
# 515         True
# 517         True
# 516         True
# 997         True
# 998         True
# 995         True
# 513         True
# 514         True
# 994         True
# 993         True
# 512         True
# 992         True
# 991         True
# 989         True
# 510         True
# 511         True
# 990         True
# 509         True
# 508         True
# 988         True
# 507         True
# 987         True
# 505         True
# 506         True
# 982         True
# 983         True
# 985         True
# 986         True
# 984         True
# 504         True
# 503         True
# 980         True
# 981         True
# 978         True
# 979         True
# 499         True
# 502         True
# 501         True
# 500         True
# 973         True
# 497         True
# 498         True
# 975         True
# 977         True
# 974         True
# 972         True
# 976         True
# 971         True

# %%
stud["math score"].quantile(0.75)
top25=stud[stud["math score"]>=77].sort_values("math score",ascending=False)
top25
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 999    male        group E           bachelor's degree      standard
# 998    male        group E          associate's degree  free/reduced
# 997    male        group D                some college      standard
# 996    male        group A                some college      standard
# 517  female        group E          associate's degree      standard
# ..      ...            ...                         ...           ...
# 854    male        group D            some high school      standard
# 855    male        group E          associate's degree  free/reduced
# 856    male        group E            some high school      standard
# 415  female        group B             master's degree  free/reduced
# 414  female        group A                 high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 999               completed         100            100            100
# 998               completed         100            100             93
# 997               completed         100             97             99
# 996               completed         100             96             86
# 517                    none         100            100            100
# ..                      ...         ...            ...            ...
# 854               completed          77             68             69
# 855               completed          77             69             68
# 856               completed          77             76             77
# 415               completed          77             97             94
# 414               completed          77             88             85
#
# [255 rows x 8 columns]
